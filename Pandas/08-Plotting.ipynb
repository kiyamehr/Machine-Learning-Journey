# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./Pandas Data/data.csv')

plt.plot(df)
plt.show()

# %%
df = pd.read_csv('./Pandas Data/data.csv')

plt.scatter(x=df['Duration'], y=df['Calories'])
plt.show()

# %%
df = pd.read_csv('./Pandas Data/data.csv')

plt.hist(df["Duration"])
plt.show()
