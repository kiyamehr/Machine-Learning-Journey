# %%
import pandas as pd

# %%
mydataset = {
    'cars' : ['BMW', 'benz', 'volkswagen'],
    'sylinder' : [6, 6, 4]
}

df = pd.DataFrame(mydataset)

print(df)
# Out:
#          cars  sylinder
# 0         BMW         6
# 1        benz         6
# 2  volkswagen         4

# %%
print(pd.__version__)
# Out:
# 3.0.3
