# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np

# %% [markdown]
# # Calculating number of hours studied

# %%
x = np.array([[1], [2], [4], [5]], dtype=np.float32) #? 4 samples 1 feature (x)
y = np.array([0, 0, 1, 1], dtype=np.float32) #? 4 labels (y)

print(x.shape, y.shape)
# Out:
# (4, 1) (4,)

# %%
model = Sequential([
    Dense(units=1, activation='sigmoid', input_shape=(1,))
])

# %%
model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step - accuracy: 0.5000 - loss: 0.6085
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5000 - loss: 0.6081
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.6077
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5000 - loss: 0.6072
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5000 - loss: 0.6068
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5000 - loss: 0.6064
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5000 - loss: 0.6060
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5000 - loss: 0.6056
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5000 - loss: 0.6052
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5000 - loss: 0.6048
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5000 - loss: 0.6044
# Epoch 12/100
# ...

# %%
y_pred = model.predict(np.array([[3]], dtype=np.float32))
y_pred
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# array([[0.65677226]], dtype=float32)

# %%
w, b= model.get_weights()

print(f'w: {w}, b: {b}')
# Out:
# w: [[0.25114277]], b: [-0.10448546]
